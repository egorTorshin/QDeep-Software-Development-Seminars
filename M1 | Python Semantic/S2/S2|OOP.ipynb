# %%
class A:
    def method(self):
        return "A's method"

class B(A):
    def method(self):
        return "B's method"

class C(A):
    def method(self):
        return "C's method"

class D(B, C):
    ...

# %%
print(D.__mro__)
# Out:
# (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>)

# %%
obj = D()
print(obj.method())
# Out:
# B's method

# %% [markdown]
# ### Incapsulation

# %%
class Cell:
    def __init__(self, user, bill):
        self.user = user
        self._bill = bill

    def get_bill(self):
        return self._bill
    
    def deposit(self, deposit):
        self._bill =  self.get_bill() + deposit

cell = Cell("Egor", 12000)

cell.deposit(2000)
print(cell.get_bill())
# Out:
# 14000

# %% [markdown]
# ### Polymorphism

# %%
class Animal:
    def __init__(self, type):
        self.type = type
    
    def greet(self):
        pass

class Lion(Animal):
    def greet(self):
        return f"{self.type} sais ROAR!!!"
    

class Dog(Animal):
    def greet(self):
        return f"{self.type} sais BARK!!!"
    


animal = Animal("animal")

dog = Dog("dog")

lion = Lion("lion")

lst = [animal, dog, lion]

for i in lst:
    print(i.greet())
# Out:
# None
# dog sais BARK!!!
# lion sais ROAR!!!

# %% [markdown]
# ### Inheritance

# %%
class Vehicle:
    def __init__(self, brand, speed):
        self.brand = brand
        self.speed = speed

    def move(self):
        return f"{self.brand} moves with speed: {self.speed} km/h"
    
class Motorcycle(Vehicle):
    def __init__(self, brand, speed):
        super().__init__(brand, speed)

    def move(self):
        return f"{self.brand} motorcycle moves with speed: {self.speed} km/h"
    
class Car(Vehicle):
    def __init__(self, brand, speed, color):
        super().__init__(brand, speed)
        self.color = color

    def move(self):
        return f"{self.brand} car moves with speed: {self.speed} km/h and {self.color} doesn't play role"


car = Car("Ferrari", 320, "red")
moto = Motorcycle("Yamaha", 200)

print(car.move())
print(moto.move())
# Out:
# Ferrari car moves with speed: 320 km/h and red doesn't play role
# Yamaha motorcycle moves with speed: 200 km/h

# %% [markdown]
# ### Abstraction

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    
    @abstractmethod
    def area(self):
        pass
    
    @abstractmethod
    def perimeter(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return 3.14 * self.radius ** 2
    
    def perimeter(self):
        return 2 * 3.14 * self.radius


class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)


circle = Circle(5)
rect = Rectangle(4, 6)

print(f"Circle - area: {circle.area():.2f}, perimeter: {circle.perimeter():.2f}")

print(f"Rectangle - area: {rect.area()}, perimeter: {rect.perimeter()}")
# Out:
# Circle - area: 78.50, perimeter: 31.40
# Rectangle - area: 24, perimeter: 20
